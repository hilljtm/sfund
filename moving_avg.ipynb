# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.style.use('seaborn')
# %matplotlib inline

# %%
df = pd.read_csv('minutebtc.csv')

df['time'] = pd.to_datetime(df['time'], unit='s')
df.head()
# Out:
#                  time fromsymbol tosymbol          open          high  \
# 0 2019-07-21 00:00:00        BTC      USD  10764.239649  10770.285645
# 1 2019-07-21 00:01:00        BTC      USD  10755.804323  10758.616456
# 2 2019-07-21 00:02:00        BTC      USD  10750.826531  10750.082678
# 3 2019-07-21 00:03:00        BTC      USD  10736.635436  10737.067952
# 4 2019-07-21 00:04:00        BTC      USD  10701.656328  10718.424974
#
#             low         close  volume_from     volume_to
# 0  10755.804323  10755.804323    29.303925  3.155317e+05
# 1  10749.186409  10750.826531    53.944469  5.795079e+05
# 2  10736.635436  10736.635436    61.728539  6.623754e+05
# 3  10700.073477  10701.656328   207.913147  2.226079e+06
# 4  10703.879943  10712.512480   132.777271  1.420546e+06

# %%
fig = plt.figure(figsize=(20,10))
_ = plt.plot(df.time, df.close)
_ = plt.show()

# %%
rolling_mean = df.close.rolling(window=20).mean()
rolling_mean2 = df.close.rolling(window=50).mean()

fig = plt.figure(figsize=(20,10))
plt.plot(df.time, df.close, label='BTC')
plt.plot(df.time, rolling_mean, label='BTC 20 day SMA', color='black', linewidth=2)
plt.plot(df.time, rolling_mean2, label='BTC 50 day SMA', color='red', linewidth=2)
plt.legend(loc='upper right')
plt.show()
